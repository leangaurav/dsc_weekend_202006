# %%
import pandas as pd

# %%
df =pd.read_csv('test.csv', names=list("abcd"))
print(df)
print()
print(df.dtypes)
# Out:
#     a    b   c  d
# 0   1  2.0   3  a
# 1  11  NaN  22  b
#
# a      int64
# b    float64
# c      int64
# d     object
# dtype: object

# %%
df = pd.read_csv(r'D:\Training\dsc_weekend_202006\Notebooks\titanic_dataset.csv')
# skip_rows = <number of rows to skip>
# index_col = <index of column to use as row index>

print(df)
df
# Out:
#       Unnamed: 0  pclass  survived  \
# 0              0       1         1
# 1              1       1         1
# 2              2       1         0
# 3              3       1         0
# 4              4       1         0
# ...          ...     ...       ...
# 1304        1304       3         0
# 1305        1305       3         0
# 1306        1306       3         0
# 1307        1307       3         0
# 1308        1308       3         0
#
#                                                  name  gender      age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                      Allison, Master. Hudson Trevor    male   0.9167      1
# 2                        Allison, Miss. Helen Loraine  female   2.0000      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
# ...

# %%
print(df.describe(include='all'))
# Out:
#          Unnamed: 0       pclass     survived              name gender  \
# count   1309.000000  1309.000000  1309.000000              1309   1309
# unique          NaN          NaN          NaN              1307      2
# top             NaN          NaN          NaN  Kelly, Mr. James   male
# freq            NaN          NaN          NaN                 2    843
# mean     654.000000     2.294882     0.381971               NaN    NaN
# std      378.020061     0.837836     0.486055               NaN    NaN
# min        0.000000     1.000000     0.000000               NaN    NaN
# 25%      327.000000     2.000000     0.000000               NaN    NaN
# 50%      654.000000     3.000000     0.000000               NaN    NaN
# 75%      981.000000     3.000000     1.000000               NaN    NaN
# max     1308.000000     3.000000     1.000000               NaN    NaN
#
#                 age        sibsp        parch    ticket    fare        cabin  \
# ...

# %%
print(df.head(100).tail(20))
# Out:
#     Unnamed: 0  pclass  survived  \
# 80          80       1         0
# 81          81       1         0
# 82          82       1         1
# 83          83       1         1
# 84          84       1         0
# 85          85       1         1
# 86          86       1         1
# 87          87       1         1
# 88          88       1         1
# 89          89       1         0
# 90          90       1         1
# 91          91       1         1
# 92          92       1         1
# 93          93       1         1
# 94          94       1         1
# 95          95       1         1
# 96          96       1         0
# 97          97       1         1
# 98          98       1         1
# 99          99       1         1
#
#                                                  name  gender   age  sibsp  \
# 80                          Crafton, Mr. John Bertram    male   NaN      0
# 81                       Crosby, Capt. Edward Gifford    male  70.0      1
# ...

# %%
print(df.tail())
# Out:
#       Unnamed: 0  pclass  survived                       name  gender   age  \
# 1304        1304       3         0       Zabour, Miss. Hileni  female  14.5
# 1305        1305       3         0      Zabour, Miss. Thamine  female   NaN
# 1306        1306       3         0  Zakarian, Mr. Mapriededer    male  26.5
# 1307        1307       3         0        Zakarian, Mr. Ortin    male  27.0
# 1308        1308       3         0         Zimmerman, Mr. Leo    male  29.0
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# 1304      1      0    2665  $14.45    NaN        C  NaN  328.0       NaN
# 1305      1      0    2665  $14.45    NaN        C  NaN    NaN       NaN
# 1306      0      0    2656   $7.23    NaN        C  NaN  304.0       NaN
# 1307      0      0    2670   $7.23    NaN        C  NaN    NaN       NaN
# 1308      0      0  315082   $7.88    NaN        S  NaN    NaN       NaN

# %%
print(df.count())
# Out:
# Unnamed: 0    1309
# pclass        1309
# survived      1309
# name          1309
# gender        1309
# age           1046
# sibsp         1309
# parch         1309
# ticket        1309
# fare          1308
# cabin          295
# embarked      1307
# boat           486
# body           121
# home.dest      745
# dtype: int64

# %%
print(df.age)
print()
print(df.age.dtype)
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64
#
# float64
